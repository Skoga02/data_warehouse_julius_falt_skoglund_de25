# %%
import requests
import json

url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))

query = "data engineer"
table_name = "data_field_job_ads"

# %%
json_response = _get_ads(query)

# %%
json_response
# Out:
# {'total': {'value': 43586},
#  'positions': 72856,
#  'query_time_in_millis': 6,
#  'result_time_in_millis': 21,
#  'stats': [],
#  'freetext_concepts': {},
#  'hits': [{'relevance': 0.0,
#    'id': '31489541',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31489541',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/2321000016/logotyper/logo.png',
#    'headline': 'Tandläkare till Folktandvården Gubbängen',
#    'application_deadline': '2026-10-06T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Vi på Folktandvården Stockholm är engagerade i att förbättra regionens munhälsa genom forskning och praktiskt arbete. Hos oss får du möjlighet att utvecklas personligt och professionellt och när du utvecklas till det bättre så gör även stockholmarnas folkhälsa det.Vi kallar det tandvård med ett gott syfte.\xa0\nDitt uppdrag\nSom tandläkare hos oss erbjuds du en central roll i vårt arbete med att erbjuda hälsofrämjande och förebyggande tandvård för alla stockholmare. Du är teamets specialist i oral diagnostik och genomför den långsiktiga helhetsbedömningen. Folktandvården Stockholm utför patientsäker vård med hög kvalité och god service vilket blir centrala delar av ditt arbete. Du genomför enklare undersökningar till mer avancerade behandlingar.\nVälkommen till Folktandvården Gubbängen!\nVi söker nu en tandläkare som vill bli en del av vårt engagerade och kompetenta team. Vår moderna och ljusa klinik ligger precis intill Gubbängens tunnelbana, endast 18 minuter från Stockholms central.\xa0\nKliniken har sju välutrustade behandlingsrum och erbjuder en arbetsmiljö där både medarbetare och patienter står i fokus. Hos oss arbetar erfarna kollegor med bred odontologisk kompetens och behandlare som sätter implantat - och vi jobbar i ett nära samarbete, kunskapsutbyte och kontinuerlig utveckling.\nVi är ett öppet och stöttande team om hjälper varandra i vardagen, delar erfarenheter och har nära till skratt, samtidigt som vi tar vårt uppdrag på största allvar. Här får du möjlighet att utvecklas i din yrkesroll och arbeta i en miljö där kvalitet, omtanke och samarbete värderas högt.\xa0\nVad du behöver för att lyckas \nVi söker dig legitimerade tandläkare, gärna med god erfarenhet och gärna inom allmäntandvårdens alla odontologiska ämnesområden. För dig är tandvård av god kvalitet en självklarhet, liksom ett professionellt bemötande till både kunder och kollegor. Du är förtroendeskapande och håller en hög servicenivå. Du har en mycket god kommunikativ förmåga i svenska språket i både tal och skrift. Som person är du positiv även i utmanande situationer och strävar efter att utveckla effektiva lösningar. Vi värdesätter dina personliga egenskaper högt.\nSom tandläkare hos oss på Folktandvården Stockholm finns det möjlighet till: \nAtt få handleda nyutexaminerade tandläkare mot ett extra arvode\nAtt få samverka och byta erfarenheter med ett stort tandläkarnätverk med stor kompetensbredd\nHelgtjänstgöring med extra helgtillägg\nKarriärutveckling inom exempelvis uppdrag såsom klinikchef, nischtandläkare och odontologisk samordnare\nAtt som nyutexaminerad gå vårt introduktionsprogram\n\nFolktandvården Stockholm erbjuder dig även olika förmåner såsom:\nFriskvårdsbidrag på 5 000 kr\nTjänstepension\nLöneväxling till pension\nExtra semesterdagar till dig över 40 år\nTillägg vid föräldraledighet\nMöjlighet till del av incitamentsmodell\nFris
></p><ul><li>Att få handleda nyutexaminerade tandläkare mot ett extra arvode</li><li>Att få samverka och byta erfarenheter med ett stort tandläkarnätverk med stor kompetensbredd</li><li>Helgtjänstgöring med extra helgtillägg</li><li>Karriärutveckling inom exempelvis uppdrag såsom klinikchef, nischtandläkare och odontologisk samordnare</li><li>Att som nyutexaminerad gå vårt introduktionsprogram</li></ul><p><strong>Folktandvården Stockholm erbjuder dig även olika förmåner såsom:</strong></p><ul><li>Friskvårdsbidrag på 5 000 kr</li><li>Tjänstepension</li><li>Löneväxling till pension</li><li>Extra semesterdagar till dig över 40 år</li><li>Tillägg vid föräldraledighet</li><li>Möjlighet till del av incitamentsmodell</li><li>Frisktandvård</li><li>Subventionerad läkarvård</li></ul><p><strong>Anställning</strong></p><p>Välkommen med din ansökan senast den 6 oktober 2026. Tjänsten är en tillsvidareanställning på heltid, med tillträde enligt överenskommelse. Provanställning kan komma att tillämpas. Urval sker löpande och det första steget i rekryteringsprocessen är ett personlighetstest samt ett problemlösningstest. Vänligen bifoga CV och kopia av din legitimation i ansökan. Om du är eller har varit anställd hos oss tidigare tar vi referenser från din klinikchef.</p><p>Inför intervju behöver du kunna styrka ditt medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du kunna visa upp ett giltigt arbetstillstånd, eller dokumentation som visar att du är undantagen från kravet. För att bli ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://www.regionstockholm.se/jobb/lediga-jobb/',
#     'organization_number': '2321000016',
#     'name': 'REGION STOCKHOLM',
#     'workplace': 'Folktandvården Stockholm, Gubbängen'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://regionstockholm.varbi.com/se/what:job/jobID:969980/type:job/where:125/apply:1',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'TdvW_S8R_CFH',
#     'label': 'Tandläkare',
#     'legacy_ams_taxonomy_id': '5724'},
#    'occupation_group': {'concept_id': 'HPxT_fQJ_zwT',
#     'label': 'Tandläkare',
#     'legacy_ams_taxonomy_id': '2260'},
#    'occupation_field': {'concept_id': 'NYW6_mP6_vwf',
#     'label': 'Hälso- och sjukvård',
#     'legacy_ams_taxonomy_id': '8'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Box 22550',
#     'postcode': '10422',
#     'city': 'Stockholm',
#     'coordinates': [18.0270445, 59.3309901]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Box 22550',
#      'postcode': '10422',
#      'city': 'Stockholm',
#      'coordinates': [18.0270445, 59.3309901]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': 'Jörgen Karlsson, TT',
#      'description': None,
#      'email': None,
#      'telephone': '08-12315231',
#      'contact_type': None}],
#    'publication_date': '2026-09-17T13:47:44',
#    'last_publication_date': '2026-10-06T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1789645664494},
#   {'relevance': 0.0,
#    'id': '31489534',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31489534',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5591520217/logotyper/logo.png',
#    'headline': 'Frukostvärd / salladsbuffévakt extrapersonal',
#    'application_deadline': '2026-10-17T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Vi på Åmåls Stadshotell söker nu en morgonpigg och serviceinriktad medarbetare till en kombinationstjänst där du arbetar som frukostvärd på morgonen och ansvarar för sallader under vår lunchbuffé.\n\n\nArbetsuppgifter\nFörbereda och ställa fram frukost\nHålla frukostbuffén välfylld och fräsch\nPlocka undan och diska efter frukosten\nFörbereda och fylla på salladsbuffén\nHa uppsikt under lunchserveringen och fylla på efter behov\n\n\n\nVi söker dig som\nÄr serviceinriktad, positiv och tycker om att möta människor\nTrivs med att arbeta tidiga morgnar\nÄr bekväm med att möta och hjälpa gäster\nHar öga för detaljer och kan arbeta strukturerat även i högt tempo\n\n\n\nKrav: \nFyllt 18 år\nKörkort\nKan arbeta vardagar och helger\n\n\n\nVi tillämpar kollektivavtal\nUrval sker löpande så vänta inte med att skicka din ansökan!',
#     'text_formatted': '<p>Vi på Åmåls Stadshotell söker nu en morgonpigg och serviceinriktad medarbetare till en kombinationstjänst där du arbetar som frukostvärd på morgonen och ansvarar för sallader under vår lunchbuffé.</p><p><br></p><p>Arbetsuppgifter</p><ul><li>Förbereda och ställa fram frukost</li><li>Hålla frukostbuffén välfylld och fräsch</li><li>Plocka undan och diska efter frukosten</li><li>Förbereda och fylla på salladsbuffén</li><li>Ha uppsikt under lunchserveringen och fylla på efter behov</li></ul><p><br></p><p>Vi söker dig som</p><ul><li>Är serviceinriktad, positiv och tycker om att möta människor</li><li>Trivs med att arbeta tidiga morgnar</li><li>Är bekväm med att möta och hjälpa gäster</li><li>Har öga för detaljer och kan arbeta strukturerat även i högt tempo</li></ul><p><br></p><p>Krav: </p><ul><li>Fyllt 18 år</li><li>Körkort</li><li>Kan arbeta vardagar och helger</li></ul><p><br></p><p>Vi tillämpar kollektivavtal</p><p>Urval sker löpande så vänta inte med att skicka din ansökan!</p><p><br></p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'kpPX_CNN_gDU',
#     'label': 'Tillsvidareanställning (inkl. eventuell provanställning)',
#     'legacy_ams_taxonomy_id': None},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#     'label': 'Deltid',
#     'legacy_ams_taxonomy_id': '2'},
#    'scope_of_work': {'min': 0, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5591520217',
#     'name': 'Ardilla aktiebolag',
#     'workplace': 'Åmåls Stadshotell'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': 'event@amalhotellen.se',
#     'via_af': False,
#     'url': None,
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': True,
#    'driving_license': None,
#    'occupation': {'concept_id': 'oRB5_b7i_Qzv',
#     'label': 'Köksbiträde',
#     'legacy_ams_taxonomy_id': '483'},
#    'occupation_group': {'concept_id': 'tPox_ie4_X9X',
#     'label': 'Restaurang- och köksbiträden m.fl.',
#     'legacy_ams_taxonomy_id': '9412'},
#    'occupation_field': {'concept_id': 'ScKy_FHB_7wT',
#     'label': 'Hotell, restaurang, storhushåll',
#     'legacy_ams_taxonomy_id': '7'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Åmål',
#     'municipality_code': '1492',
#     'municipality_concept_id': 'M1UC_Cnf_r7g',
#     'region': 'Västra Götalands län',
#     'region_code': '14',
#     'region_concept_id': 'zdoY_6u5_Krt',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Kungsgatan 9',
#     'postcode': '66231',
#     'city': 'Åmål',
#     'coordinates': [12.7059889864442, 59.0515597344769]},
#    'workplace_addresses': [{'municipality': 'Åmål',
#      'municipality_code': '1492',
#      'municipality_concept_id': 'M1UC_Cnf_r7g',
#      'region': 'Västra Götalands län',
#      'region_code': '14',
#      'region_concept_id': 'zdoY_6u5_Krt',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Kungsgatan 9',
#      'postcode': '66231',
#      'city': 'Åmål',
#      'coordinates': [12.7059889864442, 59.0515597344769]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 5,
#       'concept_id': 'oRB5_b7i_Qzv',
#       'label': 'Köksbiträde',
#       'legacy_ams_taxonomy_id': '483'}],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-09-17T13:45:45',
#    'last_publication_date': '2026-10-17T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1789645545668},
#   {'relevance': 0.0,
#    'id': '31489526',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31489526',
#    'logo_url': None,
#    'headline': 'myNanny barnvakt Stockholm, nanny / barnpassning, heltid/dagtid',
#    'application_deadline': '2026-10-01T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Få ett flexibelt och barnsligt roligt extrajobb\n\n\nPå myNanny kan du göra skillnad för familjer samtidigt som du får ett barnsligt roligt och flexibelt extrajobb. Vi är ett av Sveriges ledande barnpassningsföretag, vilket innebär att du kan förvänta dig mycket av oss – allt från bra lönevillkor till professionellt bemötande, utbildning, försäkring och personlig support.\n\n\nAnsök till jobbet som barnvakt på myNanny här: https://my-nanny.se/extrajobb-barnvakt/\n\n\nSå funkar jobbet som barnvakt \nAtt jobba som nanny är både roligt och flexibelt, du väljer själv vilka uppdrag du vill ha och när du ska jobba. Som barnvakt hjälper du en eller flera familjer i ditt område med att passa deras barn. Det kan innebära allt från hämtning på förskola/skola och en rolig stund i lekparken till att äta mellanmål eller nattning. Det viktigaste är att det är roligt och tryggt för både barnen, föräldrarna och dig!\n\n\nMer om familjen\nUnder din intervju kommer du får mer information om just denna familj, men här är några bra saker att veta:\nAntal barn: 1\nÅlder: 6 veckor\nDagar i veckan de önskar hjälp: 4 gånger i veckan\nTider: Passen startar  08:00 och varar i ca 4 timmar.\n\n\n\nExtrajobbet passar perfekt för dig som:\nÄr ansvarsfull och lekfull med ett genuint engagemang för barn\nHar erfarenhet av att ha passat ett eller flera barn (0 - 6 år) självständigt\nKan arbeta flexibelt både vardagar och helger som nanny\n\n\n\nDetta erbjuder vi dig som barnvakt på myNanny: \nKonkurrenskraftig lön med tydlig lönetrappa \nDu är alltid försäkrad under barnpassningen\nFlexibelt extrajobb med en familj som passar just dig och din vardag\nFölja och vara delaktig i ett barns utveckling \nUtbildning i hjärt- och lungräddning samt första hjälpen\nIntroduktionsutbildning av oss på myNanny \nKontinuerligt stöd från din personliga kontaktperson på myNanny\nViktiga och relevanta meriter till ditt CV\n\n\n\nAnsök till jobbet på 3-4 min \nDu ansöker till jobbet som barnvakt snabbt och enkelt här: https://my-nanny.se/extrajobb-barnvakt/ \n\n\nAnsökan tar endast några minuter och du blir sedan kallad till intervju för jobbet som nanny på myNanny. \n\n\nLäs mer om hur det är att jobba som barnvakt på myNanny på vår hemsida: https://my-nanny.se/barnvakt',
#     'text_formatted': '<p><strong>Få ett flexibelt och barnsligt roligt extrajobb</strong></p><p><br></p><p>På myNanny kan du göra skillnad för familjer samtidigt som du får ett barnsligt roligt och flexibelt extrajobb. Vi är ett av Sveriges ledande barnpassningsföretag, vilket innebär att du kan förvänta dig mycket av oss – allt från bra lönevillkor till professionellt bemötande, utbildning, försäkring och personlig support.</p><p><br></p><p>Ansök till jobbet som barnvakt på myNanny här: https://my-nanny.se/extrajobb-barnvakt/</p><p><br></p><p><strong>Så funkar jobbet som barnvakt </strong></p><p>Att jobba som nanny är både roligt och flexibelt, du väljer själv vilka uppdrag du vill ha och när du ska jobba. Som barnvakt hjälper du en eller flera familjer i ditt område med att passa deras barn. Det kan innebära allt från hämtning på förskola/skola och en rolig stund i lekparken till att äta mellanmål eller nattning. Det viktigaste är att det är roligt och tryggt för både barnen, föräldrarna och dig!</p><p><br></p><p><strong>Mer om familjen</strong></p><p>Under din intervju kommer du får mer information om just denna familj, men här är några bra saker att veta:</p><ul><li>Antal barn: 1</li><li>Ålder: 6 veckor</li><li>Dagar i veckan de önskar hjälp: 4 gånger i veckan</li><li>Tider: Passen startar  08:00 och varar i ca 4 timmar.</li></ul><p><br></p><p><strong>Extrajobbet passar perfekt för dig som:</strong></p><ul><li>Är ansvarsfull och lekfull med ett genuint engagemang för barn</li><li>Har erfarenhet av att ha passat ett eller flera barn (0 - 6 år) självständigt</li><li>Kan arbeta flexibelt både vardagar och helger som nanny</li></ul><p><br></p><p><strong>Detta erbjuder vi dig som barnvakt på myNanny: </strong></p><ul><li>Konkurrenskraftig lön med tydlig lönetrappa </li><li>Du är alltid försäkrad under barnpassningen</li><li>Flexibelt extrajobb med en familj som passar just dig och din vardag</li><li>Följa och vara delaktig i ett barns utveckling </li><li>Utbildning i hjärt- och lungräddning samt första hjälpen</li><li>Introduktionsutbildning av oss på myNanny </li><li>Kontinuerligt stöd från din personliga kontaktperson på myNanny</li><li>Viktiga och relevanta meriter till ditt CV</li></ul><p><br></p><p>Ansök till jobbet på 3-4 min </p><p>Du ansöker till jobbet som barnvakt snabbt och enkelt här: https://my-nanny.se/extrajobb-barnvakt/ </p><p><br></p><p>Ansökan tar endast några minuter och du blir sedan kallad till intervju för jobbet som nanny på myNanny. </p><p><br></p><p>Läs mer om hur det är att jobba som barnvakt på myNanny på vår hemsida: https://my-nanny.se/barnvakt </p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': '1paU_aCR_nGn',
#     'label': 'Behovsanställning',
#     'legacy_ams_taxonomy_id': '4'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': None,
#     'label': None,
#     'legacy_ams_taxonomy_id': None},
#    'working_hours_type': {'concept_id': None,
#     'label': None,
#     'legacy_ams_taxonomy_id': None},
#    'scope_of_work': {'min': None, 'max': None},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://my-nanny.se/extrajobb-barnvakt/',
#     'organization_number': '5569751901',
#     'name': 'YCLA AB',
#     'workplace': 'myNanny Barnvakt Stockholm'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://my-nanny.se/extrajobb-barnvakt/',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'd9nv_iUm_Jyg',
#     'label': 'Barnvakt',
#     'legacy_ams_taxonomy_id': None},
#    'occupation_group': {'concept_id': 'o1gn_FoS_fB7',
#     'label': 'Övrig hemservicepersonal m.fl.',
#     'legacy_ams_taxonomy_id': '9119'},
#    'occupation_field': {'concept_id': 'whao_Q6A_ScE',
#     'label': 'Sanering och renhållning',
#     'legacy_ams_taxonomy_id': '12'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'myNanny',
#     'postcode': '11350',
#     'city': 'Stockholm',
#     'coordinates': [18.055290340312897, 59.343850482911776]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'myNanny',
#      'postcode': '11350',
#      'city': 'Stockholm',
#      'coordinates': [18.055290340312897, 59.343850482911776]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-09-17T13:45:35',
#    'last_publication_date': '2026-10-01T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1789645535698},
#   {'relevance': 0.0,
#    'id': '31489546',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31489546',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5590023213/logotyper/logo.png',
#    'headline': 'Accounting Business Analyst',
#    'application_deadline': '2027-03-16T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'We’re looking for an Accounting Business Analyst for a company in Stockholm. Start is ASAP, 9 months limited contract to begin with. This role is 100% onsite in Stockholm.\n \nAccounting Business Analyst\nWe are seeking a highly experienced accounting specialists for a consulting assignment within a large-scale financial transformation initiative.\nThe role requires strong hands-on experience in accounting and reconciliation of financial records in a complex enterprise environment. You are expected to independently analyse, design and document financial business processes from multiple front-end systems, detail resulting accounting patterns, in a complex enterprise environment.\n\ufeff \nART Initiative\nThe company is running an initiative called ART, Accounting and Reporting Transformation, with the objective of moving accounting functionality from several legacy accounting solutions to a new cloud-based solution.\nIntegration with other systems is ongoing, including business applications delivering accounting data, source systems, and downstream consumers of accounting and reporting information.\n\ufeff \nThe initiative includes several agile teams working across IT development, integration, infrastructure, security, and business processes. The solution includes development of customized bank-specific functionality running on dedicated server instances in the Oracle sovereign cloud, updates to legacy systems, and configuration and integration of an accounting SaaS solution provided by Oracle.\n\ufeff \nRequired Skills & Experience\nStrong ability to analyse accounting, reconciliation and reporting requirements and translate them into process descriptions, accounting patterns and system requirements\nHands-on and broad accounting experience and confident in describing accounting scenarios, for example using T-accounts\nStrong ability to train and coach end-users to confidently and efficiently use the resulting accounting solutions\nExperience in planning, preparing and executing tests of financial processes and accounting solutions in a large, multinational enterprise\nExperience with financial services, accounting, regulatory reporting, and other highly regulated business domains\nExperience working in agile development teams and collaborating across application, integration, test, and business functions\nStrong written and spoken English communication skills\n\ufeff \nEducation\nMaster’s degree in Information Technology, Business Administration, or a related field\nEquivalent professional experience may be considered\n\ufeff \nPreferred Qualifications\nExperience in integrating large scale and custom business applications using Oracle Financials Cloud or similar, comprehensive accounting system\nExperience in Change Management, organizational transformation, and user training\n\ufeff \nKey Responsibilities\nAnalyse functional and non-functional requirements and translate those into accounting and configuration specifications\nTranslate business, accounting, reporting and reconciliation requirements into implementable system requirements\nSupport configuration, operation, and maintenance of an accounting solution based on Oracle Financials Cloud and other supporting financial solutions\nCollaborate with business stakeholders, system architects, and development teams to clarify functional and non-functional requirements\nProduce and maintain high-level and low-level design documentation and test-scripts\nSupport testing, deployment, release, troubleshooting, incident analysis, and remediation in non-production and production environments\nContribute to common accounting standards, reconciliation principles, and ways of working\nParticipate actively in agile ceremonies and cross-team planning\nShare knowledge and provide solution guidance to other project team members when required\nTraining and coaching end-users in using the configured solution\n\ufeff \nPersonal Attributes\nStrong analytical and  ...
#     'text_formatted': '<p><strong>We’re looking for an Accounting Business Analyst for a company in Stockholm. Start is ASAP, 9 months limited contract to begin with. This role is 100% onsite in Stockholm.</strong></p><p> </p><p><strong>Accounting Business Analyst</strong></p><p>We are seeking a highly experienced accounting specialists for a consulting assignment within a large-scale financial transformation initiative.</p><p>The role requires strong hands-on experience in accounting and reconciliation of financial records in a complex enterprise environment. You are expected to independently analyse, design and document financial business processes from multiple front-end systems, detail resulting accounting patterns, in a complex enterprise environment.</p><p>\ufeff </p><p><strong>ART Initiative</strong></p><p>The company is running an initiative called ART, Accounting and Reporting Transformation, with the objective of moving accounting functionality from several legacy accounting solutions to a new cloud-based solution.</p><p>Integration with other systems is ongoing, including business applications delivering accounting data, source systems, and downstream consumers of accounting and reporting information.</p><p>\ufeff </p><p>The initiative includes several agile teams working across IT development, integration, infrastructure, security, and business processes. The solution includes development of customized bank-specific functionality running on dedicated server instances in the Oracle sovereign cloud, updates to legacy systems, and configuration and integration of an accounting SaaS solution provided by Oracle.</p><p>\ufeff </p><p><strong>Required Skills &amp; Experience</strong></p><p>Strong ability to analyse accounting, reconciliation and reporting requirements and translate them into process descriptions, accounting patterns and system requirements</p><p>Hands-on and broad accounting experience and confident in describing accounting scenarios, for example using T-accounts</p><p>Strong ability to train and coach end-users to confidently and efficiently use the resulting accounting solutions</p><p>Experience in planning, preparing and executing tests of financial processes and accounting solutions in a large, multinational enterprise</p><p>Experience with financial services, accounting, regulatory reporting, and other highly regulated business domains</p><p>Experience working in agile development teams and collaborating across application, integration, test, and business functions</p><p>Strong written and spoken English communication skills</p><p>\ufeff </p><p><strong>Education</strong></p><p>Master’s degree in Information Technology, Business Administration, or a related field</p><p>Equivalent professional experience may be considered</p><p>\ufeff </p><p><strong>Preferred Qualifications</strong></p><p>Experience in integrating large scale and custom business applications using Oracle Financials Cloud or similar, comprehensive accounting system</p><p>Experience in Change Management, organizational transformation, and user training</p><p>\ufeff </p><p><strong>Key Responsibilities</strong></p><p>Analyse functional and non-functional requirements and translate those into accounting and configuration specifications</p><p>Translate business, accounting, reporting and reconciliation requirements into implementable system requirements</p><p>Support configuration, operation, and maintenance of an accounting solution based on Oracle Financials Cloud and other supporting financial solutions</p><p>Collaborate with business stakeholders, system architects, and development teams to clarify functional and non-functional requirements</p><p>Produce and maintain high-level and low-level design documentation and test-scripts</p><p>Support testing, deployment, release, troubleshooting, incident analysis, and remediation in non-production and production environments</p><p>Contribute to common accounting standards, reconciliation princip ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': '1paU_aCR_nGn',
#     'label': 'Behovsanställning',
#     'legacy_ams_taxonomy_id': '4'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': None,
#     'label': None,
#     'legacy_ams_taxonomy_id': None},
#    'working_hours_type': {'concept_id': None,
#     'label': None,
#     'legacy_ams_taxonomy_id': None},
#    'scope_of_work': {'min': None, 'max': None},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://openings.incluso.se',
#     'organization_number': '5590023213',
#     'name': 'Incluso AB',
#     'workplace': 'Incluso'},
#    'application_details': {'information': None,
#     'reference': 'teamtailor-8395178-2201931',
#     'email': None,
#     'via_af': False,
#     'url': 'https://openings.incluso.se/jobs/8395178-accounting-business-analyst/applications/new?promotion=2201931-arbetsformedlingen',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9LoK_Hba_2NG',
#     'label': 'Affärsanalytiker/Business analyst',
#     'legacy_ams_taxonomy_id': None},
#    'occupation_group': {'concept_id': 'Qo7p_wjf_gtv',
#     'label': 'Lednings- och organisationsutvecklare',
#     'legacy_ams_taxonomy_id': '2421'},
#    'occupation_field': {'concept_id': 'X82t_awd_Qyc',
#     'label': 'Administration, ekonomi, juridik',
#     'legacy_ams_taxonomy_id': '1'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Gamla Brogatan 32',
#     'postcode': '11120',
#     'city': 'Stockholm',
#     'coordinates': [18.0588645841847, 59.33372965719]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Gamla Brogatan 32',
#      'postcode': '11120',
#      'city': 'Stockholm',
#      'coordinates': [18.0588645841847, 59.33372965719]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-09-17T13:45:14',
#    'last_publication_date': '2027-03-16T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1789645514321},
#   {'relevance': 0.0,
#    'id': '31489532',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31489532',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/2120002437/logotyper/logo.png',
#    'headline': 'Vaktmästare till kontorsservice',
#    'application_deadline': '2026-10-16T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Vill du vara med och göra skillnad? Då är det kanske dig vi söker som medarbetare till Sollefteå kommun. Hos oss har du nära till storslagen natur och småstadscharm. Du kan njuta av ett varierat fritids- och kulturliv.\n\nFör oss är det viktigt att du känner att ditt arbete är meningsfullt och att du ser din del i helheten. Du är med och utvecklar verksamheten mot kommunens övergripande vision och mål. Här bor människor med stark framtidstro!\n\nKontorsservice består av ett team om 19 personer vars främsta uppdrag är att leverera service och stöd till alla anställda inom Sollefteå kommun när det kommer till service och underhåll av olika verksamhetsytor inom kommunen.\n\nNu söker vi en händig och serviceinriktad person till vårt team, är du den vi söker?\n\nVälkommen till oss!\r\n\r\n1 plats(er). \r\n\r\nARBETSUPPGIFTER\r\nI rollen som vaktmästare hos oss på kontorsservice kommer dina främsta arbetsuppgifter bestå av att sköta, reparera och underhålla olika verksamhetsytor inom kommunen, såväl inomhus som utomhus. Andra vanligt förekommande arbetsuppgifter i rollen kan vara att flytta och montera olika typer av möblemang och utrustning samt inreda, städa och iordningställa lokaler. Du kommer även att genomföra enklare reparationer och service inom el, VVS och viss teknisk utrustning.\n\nDu kommer att ha stora delar av dina arbetsuppgifter i västraområdet, och beroende på var man behöver din hjälp kommer hela kommunen med dess olika verksamheter att vara din arbetsplats.\r\n\r\nKVALIFIKATIONER\r\nVi söker i första hand dig som har en yrkesteknisk inriktad gymnasieutbildning i bagaget, och/eller dig som har arbetat med liknande arbetsuppgifter tidigare. Kanske har du läst byggprogrammet, eller har jobbat som vaktmästare alternativt hantverkare tidigare? Det är önskvärt, men inte ett krav, om du dessutom har utbildningarna heta arbeten, mobila arbetsplattformar eller liknande utbildningar.\n\nDå dina arbetsuppgifter till största del består av reparationer, service och underhåll är det viktigt att du är noggrann och inte tummar på kvalitén. I denna roll kommer du dagligen ha kontakt med människor, främst med medarbetare inom organisation men också med vissa externa kontakter, det är därför viktigt att du uppskattar mötet med olika människor och drivs av att leverera suverän service i alla lägen.\n\nAtt en arbetsdag kan förändras snabbt är inget som stör dig, du har ett lösningsorienterat förhållningssätt och har lätt för att ställa om, prioritera och stötta dina kollegor där det behövs. Arbetet består stundtals av fysiskt krävande arbetsuppgifter, det är därför viktigt att du har en god fysisk och uppskattar att arbeta med kroppen.\n\nKort och gott är du en händig och lösningsfokuserad person som uppskattar varierande arbetsuppgifter i olika miljöer. Du tar ansvar för att lära dig det du behöver och för att kunna göra nytta under din arbetsdag.\n\nKörkort (manuell) samt att du behärskar svenska i tal och skrift är ett krav.\n\nEtt blankt utdrag ur belastningsregister är ett krav för denna tjänst då delar av jobbet sker på skolor och förskolor.\r\n\r\nAnställningsform: Tillsvidareanställning.\r\nVaraktighet: Tillsvidare, tillträde: Enligt överenskommelse.\r\n\r\nI Sollefteå kommun är ett antal tjänster inplacerade i säkerhetsklass enligt säkerhetsskyddslagen (2018:585). För de tjänsterna ingår säkerhetsprövning i anställningsförfarandet.\n\nRegisterutdrag: För tjänster inom äldreomsorg, verksamhet för personer med funktionsnedsättning samt verksamhet för barn och ungdomar, ingår kontroll av registerutdrag som en del av rekryteringsprocessen. Blankett för att beställa ett registerutdrag finns att ladda ner från Polisens webbplats: http://polisen.se\n\nObservera att vi endast tar emot ansökningar via Offentliga jobb.\n\nFörsta gången du söker ett jobb via Offentliga jobb, registrerar du dig på länken www.offentligajobb.se och skriver in dina uppgifter där. Du bör vara noggrann när du fyller i dina uppgifte ...
#     'text_formatted': 'Vill du vara med och göra skillnad? Då är det kanske dig vi söker som medarbetare till Sollefteå kommun. Hos oss har du nära till storslagen natur och småstadscharm. Du kan njuta av ett varierat fritids- och kulturliv.\n\nFör oss är det viktigt att du känner att ditt arbete är meningsfullt och att du ser din del i helheten. Du är med och utvecklar verksamheten mot kommunens övergripande vision och mål. Här bor människor med stark framtidstro!\n\nKontorsservice består av ett team om 19 personer vars främsta uppdrag är att leverera service och stöd till alla anställda inom Sollefteå kommun när det kommer till service och underhåll av olika verksamhetsytor inom kommunen.\n\nNu söker vi en händig och serviceinriktad person till vårt team, är du den vi söker?\n\nVälkommen till oss!\r\n\r\n1 plats(er). \r\n\r\nARBETSUPPGIFTER\r\nI rollen som vaktmästare hos oss på kontorsservice kommer dina främsta arbetsuppgifter bestå av att sköta, reparera och underhålla olika verksamhetsytor inom kommunen, såväl inomhus som utomhus. Andra vanligt förekommande arbetsuppgifter i rollen kan vara att flytta och montera olika typer av möblemang och utrustning samt inreda, städa och iordningställa lokaler. Du kommer även att genomföra enklare reparationer och service inom el, VVS och viss teknisk utrustning.\n\nDu kommer att ha stora delar av dina arbetsuppgifter i västraområdet, och beroende på var man behöver din hjälp kommer hela kommunen med dess olika verksamheter att vara din arbetsplats.\r\n\r\nKVALIFIKATIONER\r\nVi söker i första hand dig som har en yrkesteknisk inriktad gymnasieutbildning i bagaget, och/eller dig som har arbetat med liknande arbetsuppgifter tidigare. Kanske har du läst byggprogrammet, eller har jobbat som vaktmästare alternativt hantverkare tidigare? Det är önskvärt, men inte ett krav, om du dessutom har utbildningarna heta arbeten, mobila arbetsplattformar eller liknande utbildningar.\n\nDå dina arbetsuppgifter till största del består av reparationer, service och underhåll är det viktigt att du är noggrann och inte tummar på kvalitén. I denna roll kommer du dagligen ha kontakt med människor, främst med medarbetare inom organisation men också med vissa externa kontakter, det är därför viktigt att du uppskattar mötet med olika människor och drivs av att leverera suverän service i alla lägen.\n\nAtt en arbetsdag kan förändras snabbt är inget som stör dig, du har ett lösningsorienterat förhållningssätt och har lätt för att ställa om, prioritera och stötta dina kollegor där det behövs. Arbetet består stundtals av fysiskt krävande arbetsuppgifter, det är därför viktigt att du har en god fysisk och uppskattar att arbeta med kroppen.\n\nKort och gott är du en händig och lösningsfokuserad person som uppskattar varierande arbetsuppgifter i olika miljöer. Du tar ansvar för att lära dig det du behöver och för att kunna göra nytta under din arbetsdag.\n\nKörkort (manuell) samt att du behärskar svenska i tal och skrift är ett krav.\n\nEtt blankt utdrag ur belastningsregister är ett krav för denna tjänst då delar av jobbet sker på skolor och förskolor.\r\n\r\nAnställningsform: Tillsvidareanställning.\r\nVaraktighet: Tillsvidare, tillträde: Enligt överenskommelse.\r\n\r\nI Sollefteå kommun är ett antal tjänster inplacerade i säkerhetsklass enligt säkerhetsskyddslagen (2018:585). För de tjänsterna ingår säkerhetsprövning i anställningsförfarandet.\n\nRegisterutdrag: För tjänster inom äldreomsorg, verksamhet för personer med funktionsnedsättning samt verksamhet för barn och ungdomar, ingår kontroll av registerutdrag som en del av rekryteringsprocessen. Blankett för att beställa ett registerutdrag finns att ladda ner från Polisens webbplats: http://polisen.se\n\nObservera att vi endast tar emot ansökningar via Offentliga jobb.\n\nFörsta gången du söker ett jobb via Offentliga jobb, registrerar du dig på länken www.offentligajobb.se och skriver in dina uppgifter där. Du bör vara noggrann när du fyller i dina uppgifter, ef ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2120002437',
#     'name': 'Sollefteå kommun',
#     'workplace': 'Sollefteå kommun, Teknik & service'},
#    'application_details': {'information': None,
#     'reference': 'C344989',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=956548d8-03f1-44e9-b5c6-1db7784274ef&publishCode=PB&TK=b225267f-b4d7-43b1-b2c4-76b504afaf47',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': True,
#    'driving_license': [{'concept_id': 'VTK8_WRx_GcM',
#      'label': 'B',
#      'legacy_ams_taxonomy_id': '3'}],
#    'occupation': {'concept_id': 'GtM1_tT6_UUy',
#     'label': 'Kontorsvaktmästare',
#     'legacy_ams_taxonomy_id': '4136'},
#    'occupation_group': {'concept_id': '9DdK_AZY_ZNK',
#     'label': 'Vaktmästare m.fl.',
#     'legacy_ams_taxonomy_id': '9622'},
#    'occupation_field': {'concept_id': 'yhCP_AqT_tns',
#     'label': 'Installation, drift, underhåll',
#     'legacy_ams_taxonomy_id': '10'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Sollefteå',
# ...
#     'text_formatted': '<p><em>ALS Scandinavia AB är ett företag inom ALS Group, ett av de största uppdragslaboratorierna för kemiska analyser i världen. I Norden är vi ca 420 anställda inom ALS med laboratorier i Sverige; Luleå, Stockholm, Landskrona, Danmark; Humlebæk, Odense samt i Oslo och Helsingfors.</em></p><p><em>I Stockholm (Danderyd) har vi ett laboratorium med fokus på analyser med korta svarstider. Det gäller framförallt organiska föreningar, metaller och fysikaliska kemiska parametrar i jord och vatten.</em></p><p>Läs mer på <em>www.alsglobal.se</em></p><p><br></p><p><strong>Vi förstärker vårt nordiska utvecklingsteam</strong></p><p>Är du en erfaren kemist med djup kompetens inom PFAS och ett starkt driv att utveckla analysverksamhet i en nordisk miljö?</p><p>Vi söker nu en specialist inom PFAS-analyser till en nyckelroll med ansvar för metodutveckling, kvalitetssäkring och teknisk utveckling inom PFAS-området.</p><p>Detta är en strategiskt viktig roll för vår fortsatta satsning inom PFAS, där du får möjlighet att kombinera specialistkunskap och utvecklingsarbete i en verksamhet med höga kvalitetskrav, avancerad laboratoriemiljö och starkt kundfokus.</p><p><strong>Om tjänsten </strong></p><p>Som Utvecklingskemist inom PFAS blir du en teknisk nyckelperson i vårt regionala utvecklingsteam. Rollen innebär ett nära samarbete med laboratorier i Norden och ett viktigt ansvar för att utveckla och stärka vår PFAS-verksamhet. Rollen kombinerar strategiskt utvecklingsarbete med praktiskt laborativt arbete, inklusive instrumenthandhavande, felsökning och kvalitetssäkring.</p><p>Rollen innebär ett stort eget ansvar och goda möjligheter att påverka metodval, teknisk inriktning och arbetssätt inom PFAS-området.</p><p><strong>Du kommer bland annat att ansvara för att:</strong></p><ul><li>utveckla, optimera och implementera robusta PFAS‑metoder med fokus på avancerade tillämpningar inom LC‑MS/MS</li><li>effektivisera analysflöden och produktionsprocesser genom automatisering och förbättrade kontrollsystem</li><li>driva tekniska förbättringsprojekt mellan laboratorier i Norden och säkerställa harmoniserade arbetssätt</li><li>identifiera och implementera global best practice inom PFAS</li></ul><p>Du kommer främst att leda metodutveckling, validering och verifiering av metod för analys av PFAS med tekniken LC-MS/MS vid vårt laboratorium i Danderyd. I rollen ingår även att ta fram instruktioner, utbilda kollegor och bidra till kompetensutveckling inom verksamheten.</p><p>Vidare kommer du att ge stöd till de lokala PFAS ansvariga och övrig personal inom PFAS analyser samt viss teknisk rådgivning och konsultation till kunder, både internt och externt.</p><p>Vi är ett ackrediterat laboratorium enligt ISO 17025 och erbjuder våra kunder korta leveranstider. Det innebär att arbetet behöver utföras effektivt, strukturerat och med hög kvalitet.</p><p>Rollen innebär även ansvar för att arbeta enligt gällande HSE-, säkerhets- och miljökrav samt att bidra till ett säkert och hållbart laboratoriearbete.</p><p> </p><p><strong>Egenskaper</strong></p><p>Vi söker dig som har akademisk utbildning, motsvarande magisternivå, inom analytisk kemi, med flera års erfarenhet av PFAS analyser.</p><p><strong>Du har:</strong></p><ul><li>dokumenterad erfarenhet av PFAS‑analys med LC‑MS/MS</li><li>vana av metodvalidering enligt ISO 17025</li><li>erfarenhet av tekniska förbättringar och processeffektivisering samt projektledning</li><li>stark analytisk förmåga och problemlösningskompetens</li></ul><p> </p><p>För att trivas med arbetsuppgifterna bör du vara analytisk, strukturerad och kvalitetsmedveten, samt ha förmåga att självständigt driva metodutvecklingsarbete från idé till implementering. Rollen innebär även resor inom Norden, vilket kräver att du trivs i en regional och samverkande miljö.</p><p>Det är viktigt att du behärskar svenska och engelska väl i både skrift och tal samt har erfarenhet av rådgivning.</p><p><strong>Arbetstid</strong></p><p>Arbetstiden ä ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'kpPX_CNN_gDU',
#     'label': 'Tillsvidareanställning (inkl. eventuell provanställning)',
#     'legacy_ams_taxonomy_id': None},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://www.alsglobal.se',
#     'organization_number': '5565718318',
#     'name': 'ALS Scandinavia Aktiebolag',
#     'workplace': 'Als Scandinavia AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://alsglobal.wd103.myworkdayjobs.com/External/job/Stockholm-Sverige/Utvecklingskemist---med-expertkompetens-inom-PFAS_R9005',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'KZsj_HrG_iKS',
#     'label': 'Analytisk kemist',
#     'legacy_ams_taxonomy_id': '1836'},
#    'occupation_group': {'concept_id': 'eofS_oZs_RZi',
#     'label': 'Kemister',
#     'legacy_ams_taxonomy_id': '2113'},
#    'occupation_field': {'concept_id': 'kJeN_wmw_9wX',
#     'label': 'Naturvetenskap',
#     'legacy_ams_taxonomy_id': '14'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Danderyd',
#     'municipality_code': '0162',
#     'municipality_concept_id': 'E4CV_a5E_ucX',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Rinkebyvägen 19 C',
#     'postcode': '18236',
#     'city': 'Danderyd',
#     'coordinates': [18.03804397080272, 59.41567576269363]},
#    'workplace_addresses': [{'municipality': 'Danderyd',
#      'municipality_code': '0162',
#      'municipality_concept_id': 'E4CV_a5E_ucX',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Rinkebyvägen 19 C',
#      'postcode': '18236',
#      'city': 'Danderyd',
#      'coordinates': [18.03804397080272, 59.41567576269363]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [{'weight': 5,
#       'concept_id': 'zSLA_vw2_FXN',
#       'label': 'Svenska',
#       'legacy_ams_taxonomy_id': '502'}],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-09-17T13:44:30',
#    'last_publication_date': '2026-10-31T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1789645470674},
#   {'relevance': 0.0,
#    'id': '31489504',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31489504',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5569870750/logotyper/logo.png',
#    'headline': 'Är du utbildad som sanerare och vill ta nästa steg?',
#    'application_deadline': '2027-03-16T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Är du utbildad som sanerare och vill ta nästa steg?\nVi söker nu en utbildad och engagerad sanerare för rekrytering till vår kund Hasse Bygg & Ventilation AB i Göteborg. Tjänsten har omgående start, och vi söker dig som är redo att komma in i arbetet och bli en del av teamet.\nOm tjänsten\nSom sanerare kommer du att arbeta med varierande saneringsuppdrag. Arbetet kräver att du är noggrann, säkerhetsmedveten och ansvarstagande samt har kunskap om de rutiner och säkerhetsföreskrifter som gäller inom saneringsarbete.\n\nArbetsuppgifter\nUtföra olika typer av saneringsarbeten\nHantera material, verktyg och utrustning på ett säkert sätt\nFölja gällande säkerhets- och arbetsmiljörutiner\nSäkerställa att arbetet utförs noggrant och med hög kvalitet\nSamarbeta med kollegor och arbetsledning\nBidra till en säker
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'qQUd_4qe_NDT',
#     'label': '6 månader eller längre',
#     'legacy_ams_taxonomy_id': '2'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://jobb.nordiskkompetens.se',
#     'organization_number': '5569870750',
#     'name': 'Nordisk kompetens AB',
#     'workplace': 'Nordisk Kompetens'},
#    'application_details': {'information': None,
#     'reference': 'teamtailor-8395261-2201929',
#     'email': None,
#     'via_af': False,
#     'url': 'https://jobb.nordiskkompetens.se/jobs/8395261-ar-du-utbildad-som-sanerare-och-vill-ta-nasta-steg/applications/new?promotion=2201929-arbetsformedlingen',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '2eTw_69k_MEy',
#     'label': 'Saneringsarbetare',
#     'legacy_ams_taxonomy_id': '6197'},
#    'occupation_group': {'concept_id': 'idjo_2Wr_a3E',
#     'label': 'Saneringsarbetare m.fl.',
#     'legacy_ams_taxonomy_id': '7134'},
#    'occupation_field': {'concept_id': 'whao_Q6A_ScE',
#     'label': 'Sanering och renhållning',
#     'legacy_ams_taxonomy_id': '12'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Göteborg',
#     'municipality_code': '1480',
#     'municipality_concept_id': 'PVZL_BQT_XtL',
#     'region': 'Västra Götalands län',
#     'region_code': '14',
#     'region_concept_id': 'zdoY_6u5_Krt',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Johan Gertssons gata',
#     'postcode': '41512',
#     'city': 'Gothenburg',
#     'coordinates': [12.0059580772328, 57.7285047060767]},
#    'workplace_addresses': [{'municipality': 'Göteborg',
#      'municipality_code': '1480',
#      'municipality_concept_id': 'PVZL_BQT_XtL',
#      'region': 'Västra Götalands län',
#      'region_code': '14',
#      'region_concept_id': 'zdoY_6u5_Krt',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Johan Gertssons gata',
#      'postcode': '41512',
#      'city': 'Gothenburg',
#      'coordinates': [12.0059580772328, 57.7285047060767]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-09-17T13:44:11',
#    'last_publication_date': '2027-03-16T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1789645451014}]}

# %%
json_response["hits"][0]
# Out:
# {'relevance': 0.0,
#  'id': '31489541',
#  'external_id': None,
#  'original_id': None,
#  'label': [],
#  'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31489541',
#  'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/2321000016/logotyper/logo.png',
#  'headline': 'Tandläkare till Folktandvården Gubbängen',
#  'application_deadline': '2026-10-06T23:59:59',
#  'number_of_vacancies': 1,
#  'description': {'text': 'Vi på Folktandvården Stockholm är engagerade i att förbättra regionens munhälsa genom forskning och praktiskt arbete. Hos oss får du möjlighet att utvecklas personligt och professionellt och när du utvecklas till det bättre så gör även stockholmarnas folkhälsa det.Vi kallar det tandvård med ett gott syfte.\xa0\nDitt uppdrag\nSom tandläkare hos oss erbjuds du en central roll i vårt arbete med att erbjuda hälsofrämjande och förebyggande tandvård för alla stockholmare. Du är teamets specialist i oral diagnostik och genomför den långsiktiga helhetsbedömningen. Folktandvården Stockholm utför patientsäker vård med hög kvalité och god service vilket blir centrala delar av ditt arbete. Du genomför enklare undersökningar till mer avancerade behandlingar.\nVälkommen till Folktandvården Gubbängen!\nVi söker nu en tandläkare som vill bli en del av vårt engagerade och kompetenta team. Vår moderna och ljusa klinik ligger precis intill
borgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du kunna visa upp ett giltigt arbetstillstånd, eller dokumentation som visar att du är undantagen från kravet. För att bli a ...
#   'company_information': None,
#   'needs': None,
#   'requirements': None,
#   'conditions': None},
#  'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#   'label': 'Vanlig anställning',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#   'label': 'Fast månads- vecko- eller timlön',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_description': None,
#  'duration': {'concept_id': 'a7uU_j21_mkL',
#   'label': 'Tills vidare',
#   'legacy_ams_taxonomy_id': '1'},
#  'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#   'label': 'Heltid',
#   'legacy_ams_taxonomy_id': '1'},
#  'scope_of_work': {'min': 100, 'max': 100},
#  'access': None,
#  'employer': {'phone_number': None,
#   'email': None,
#   'url': 'https://www.regionstockholm.se/jobb/lediga-jobb/',
#   'organization_number': '2321000016',
#   'name': 'REGION STOCKHOLM',
#   'workplace': 'Folktandvården Stockholm, Gubbängen'},
#  'application_details': {'information': None,
#   'reference': None,
#   'email': None,
#   'via_af': False,
#   'url': 'https://regionstockholm.varbi.com/se/what:job/jobID:969980/type:job/where:125/apply:1',
#   'other': None},
#  'experience_required': True,
#  'access_to_own_car': False,
#  'driving_license_required': False,
#  'driving_license': None,
#  'occupation': {'concept_id': 'TdvW_S8R_CFH',
#   'label': 'Tandläkare',
#   'legacy_ams_taxonomy_id': '5724'},
#  'occupation_group': {'concept_id': 'HPxT_fQJ_zwT',
#   'label': 'Tandläkare',
#   'legacy_ams_taxonomy_id': '2260'},
#  'occupation_field': {'concept_id': 'NYW6_mP6_vwf',
#   'label': 'Hälso- och sjukvård',
#   'legacy_ams_taxonomy_id': '8'},
#  'workplace_model': {'concept_id': 'ZxwM_gtz_n61', 'label': 'Arbete på plats'},
#  'workplace_address': {'municipality': 'Stockholm',
#   'municipality_code': '0180',
#   'municipality_concept_id': 'AvNB_uwa_6n6',
#   'region': 'Stockholms län',
#   'region_code': '01',
#   'region_concept_id': 'CifL_Rzy_Mku',
#   'country': 'Sverige',
#   'country_code': '199',
#   'country_concept_id': 'i46j_HmG_v64',
#   'street_address': 'Box 22550',
#   'postcode': '10422',
#   'city': 'Stockholm',
#   'coordinates': [18.0270445, 59.3309901]},
#  'workplace_addresses': [{'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Box 22550',
#    'postcode': '10422',
#    'city': 'Stockholm',
#    'coordinates': [18.0270445, 59.3309901]}],
#  'must_have': {'skills': [],
#   'languages': [],
#   'work_experiences': [],
#   'education': [],
#   'education_level': []},
#  'nice_to_have': {'skills': [],
#   'languages': [],
#   'work_experiences': [],
#   'education': [],
#   'education_level': []},
#  'application_contacts': [{'name': 'Jörgen Karlsson, TT',
#    'description': None,
#    'email': None,
#    'telephone': '08-12315231',
#    'contact_type': None}],
#  'publication_date': '2026-09-17T13:47:44',
#  'last_publication_date': '2026-10-06T23:59:59',
#  'removed': False,
#  'removed_date': None,
#  'source_type': 'VIA_JOBPOSTING',
#  'timestamp': 1789645664494}
